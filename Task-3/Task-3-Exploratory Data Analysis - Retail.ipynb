# %% [markdown]
# ## The Sparks Foundation: GRIP APRIL-2023
# ## Data Science & Business Analytics Intern

# %% [markdown]
# ## *Author : Abhishek Mohapatra*

# %% [markdown]
# ## Task-3: Exploratory Data Analysis - Retail

# %% [markdown]
# ## Objective:
#  - Perform ‘Exploratory Data Analysis(EDA)’ on dataset ‘SampleSuperstore’ and try to find out the weak areas where you can
# work to make more profit.
#
#  - What all business problems you can derive by exploring the data?

# %% [markdown]
# ## Importing all the required libraries

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv("SampleSuperstore.csv")
print("Superstore dataset loaded successfully!!!")
# Out:
# Superstore dataset loaded successfully!!!

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data Preprocessing

# %%
# displaying the whole dataset
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# displaying first 5 records from the dataset
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# displaying last 5 records from the dataset
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# get the dimensions of dataset
df.shape
# Out:
# (9994, 13)

# %%
# get the brief description about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# gives statistical description about dataset
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# check for null values in dataset
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# check for duplicates data
df.duplicated().sum()
# Out:
# 17

# %%
# drop the duplicate rows of data from dataset
df.drop_duplicates(inplace = True)    # perform changes on original df and doesn't return anything

# %%
# check for duplicate data again and the dimensions of array dataset after dropping

print(df.duplicated().sum())
print(df.shape)
# Out:
# 0
# (9977, 13)

# %%
# dropping the features which are not required from the dataset
df = df.drop('Postal Code', axis=1)
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(8,5))

#correlation matrix using heatmap to check pairwise dependency between variables/columns/attributes
sns.heatmap(df.corr(), cmap = 'magma', annot = True, linewidth = 1)

#annot = True: write the data value in each cell

# %% [markdown]
# ### From above heatmap we can infer that:
#  - Sales and Profit are Moderately(positively) Correlated.
#  - Quantity and Discount are less correlated.
#  - Profit and Discount as well as Sales and Discount are negatively correlated.

# %%
#Plotting pairwise relationships in a dataset using pairplot
sns.pairplot(df, diag_kind="hist")

# %% [markdown]
# ### We can observe from above plot that:
#  - As Sales increase,Profit also increases,
#  - When Discount is more than 30%, Profit decreases, &
#  - As Discount increases, Sales decreases.

# %% [markdown]
# ## Boxplot for Sales(Univariate Data)

# %%
df.boxplot(column = "Sales")
plt.show()

# %% [markdown]
# ### Handling Outliers

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3 = col.quantile([0.25, 0.75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5*IQR)
    upper_range = Q3+(1.5*IQR)
    return lower_range, upper_range

# %%
lowp, upperp = remove_outlier(df['Sales'])
df['Sales'] = np.where(df['Sales']>upperp, upperp, df['Sales'])
df['Sales'] = np.where(df['Sales']<lowp, lowp, df['Sales'])

# %% [markdown]
# ### Boxplot for Sales after removing outliers

# %%
df.boxplot(column = "Sales")
plt.show()

# %% [markdown]
# ## Boxplot for Profit

# %%
df.boxplot(column = "Profit")
plt.show()

# %% [markdown]
# ### Handling Outliers

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3 = col.quantile([0.25, 0.75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5*IQR)
    upper_range = Q3+(1.5*IQR)
    return lower_range, upper_range

# %%
lowp, upperp = remove_outlier(df['Profit'])
df['Profit'] = np.where(df['Profit']>upperp, upperp, df['Profit'])
df['Profit'] = np.where(df['Profit']<lowp, lowp, df['Profit'])

# %% [markdown]
# ### Boxplot for Profit after removing outliers

# %%
df.boxplot(column = "Profit")
plt.show()

# %% [markdown]
# ## >> Ship Mode wise Sale Analysis

# %%
df['Ship Mode'].value_counts()  #returns count of unique value in the dataframe
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
#sns.catplot("Ship Mode", hue="Segment", data=df, kind="count", aspect=1.5, palette="Set1")
plt.figure(figsize=(9,5))
sns.countplot("Ship Mode", data=df, palette="Set1_r")
plt.show()

# %%
sns.pairplot(df, hue="Ship Mode")

# %% [markdown]
# - Standard Class is most opted Ship Mode and Same Day is least opted Ship Mode in Superstore.

# %% [markdown]
# ## >> Region wise Sale Analysis

# %%
df['Region'].value_counts()     # returns count of unique value in the data
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
plt.figure(figsize = (10,6))
sns.set(font_scale=1.2)
sns.barplot(x='Region', y='Profit', data=df, hue='Segment', palette="magma")
plt.title("Profit across different Regions(by Segments)", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.8))
plt.show()

# %% [markdown]
#  - Overall each segment is profitable as we see above.

# %%
df['Region'].value_counts().plot(kind="pie",figsize=(7,7),autopct="%1.1f%%",fontsize = 15, shadow=True,
                                 explode=[0.02,0.02,0.02,0.02], colors = ["mediumpurple","deeppink", "gold", "khaki"])
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %% [markdown]
# - Sales are mostly done in Western region and least in Southern region.

# %% [markdown]
# ### Region wise Ship Mode Analysis

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Region", hue="Ship Mode", data=df)
plt.title("Region wise Ship Mode Count", fontsize=20)
plt.ylabel("Ship Mode Count")
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.8))
plt.show()

# %% [markdown]
# **Observation**: We can also observe from above plot that Standard Class is most opted Ship Mode and Same Day is least opted Ship Mode among different regions.

# %% [markdown]
# ### Sales and Profits for different Regions

# %%
rsp = df.groupby("Region")[["Sales","Profit"]].sum().sort_values(by=["Sales","Profit"],ascending=False)
rsp.plot(kind="bar", fontsize=13, color=["cornflowerblue","lightsalmon"])
plt.xticks(rotation=0)
plt.xlabel("Region", fontsize=15)
plt.ylabel("Sales and Profit", fontsize=15)
plt.title("Sales and Profit distribution among Regions", fontsize=20)
plt.show()

# %% [markdown]
# - We can observe that: Western regions has more sales and profit followed by Eastern region then Central region and then South region.

# %% [markdown]
# ## >> City wise Sale Analysis

# %%
df['City'].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Layton             1
# Holyoke            1
# Missoula           1
# Abilene            1
# Melbourne          1
# Name: City, Length: 531, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df['City'], order=(df['City'].value_counts().head(50)).index)
#sns.countplot(x=df['City'], order=(df['City'].value_counts().head(50)).nlargest(n = 10).index)
plt.xticks(rotation=80)
plt.xlabel('City', fontsize = 20)
plt.ylabel('Count / No.of buyers', fontsize = 20)
plt.title('Citywise Analysis of buyers', fontsize = 22)
plt.show()

# %% [markdown]
# - New York City has highest count of buyers followed by Los Angeles and then by Philadelphia.

# %%
df['City'].value_counts().mean()
# Out:
# 18.789077212806028

# %% [markdown]
# ## >> State wise Sale Analysis

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df['State'], order=(df['State'].value_counts().head(50)).index)
plt.xticks(rotation=80)
plt.xlabel('States', fontsize = 20)
plt.ylabel('Count / No.of buyers', fontsize = 20)
plt.title('Statewise Analysis of buyers', fontsize = 22)
plt.show()

# %% [markdown]
# - **Observation**: California, New York, Texas has highest count of buyers/deals whereas Wyoming has least count.

# %%
df['State'].value_counts().mean()
# Out:
# 203.6122448979592

# %%
ss=df.groupby(["State"]).Sales.sum()
sp=df.groupby(["State"]).Profit.sum()

# %%
#State wise Distribution of Sales
ss.sort_values(ascending=False).plot(kind="bar",figsize=(15,6))
plt.xlabel("States")
plt.ylabel("Sales")

#State wise Distribution of Profit
sp.sort_values(ascending=False).sort_values(ascending=False).plot(kind="bar",figsize=(15,6),color="red")
plt.title("Distribution of Sales and Profit in each State", fontsize=24)
plt.xticks(rotation=80)
plt.xlabel("States", fontsize=18)
plt.ylabel("Sales and Profit", fontsize=18)  #Profit
plt.show()

# %% [markdown]
# ### We can observe :
#  - California and New York has maximum Sales and Profit.
#  - Texas and Pennsylvania has minimum Sales as well as profit.

# %% [markdown]
# ## >> Segment wise Sale Analysis

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
df['Segment'].value_counts().plot(kind="pie",figsize=(7,7),autopct="%1.1f%%",fontsize = 15, 
                                  shadow=True, explode=[0.04,0.04,0.04], colors=["mediumseagreen","hotpink","royalblue"])
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.8))
plt.show()

# %% [markdown]
# - **OBSERVATION** : Consumer sales are 51.9% which is highest amongst all and lowest is of Home Office with 17.8%.

# %% [markdown]
# ### Sales and Profits for different Segment

# %%
#Sales and Profits for each Segment
df.groupby("Segment")[["Sales","Profit"]].sum().plot(kind="bar",figsize=(8,5), fontsize=12, color=["rebeccapurple","deeppink"])
plt.ylabel("Sales and Profit", fontsize=15)
plt.xticks(rotation=0)
plt.xlabel("Segment", fontsize=15)
plt.title("Sales and Profit distribution among segments", fontsize=20)
plt.show()

# %% [markdown]
# **Observation**: Consumer Segment has higher sales as well as more profit and Home Office Segment has least sales among all.

# %% [markdown]
# ## >> Category wise Analysis

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.barplot(x='Category', y='Sales', data=df, palette="CMRmap")
plt.title("Barplot of Category and Sales", fontsize = 15)
plt.show()

# %% [markdown]
# - Sales are mostly in Technology and Furniture Category.

# %%
sns.barplot(x='Category', y='Profit', data=df, palette="CMRmap")
plt.title("Barplot of Category and Profit", fontsize = 15)
plt.show()

# %% [markdown]
# - There is more profit in Technology Category and moderate in Furniture and Office Supplies category.

# %%
csp = df.groupby("Category")[["Sales","Profit"]].sum().sort_values(by=["Sales","Profit"], ascending = True)
csp.plot(kind="bar",fontsize=13, color = ["orange", "green"])
plt.xticks(rotation=0)
plt.xlabel("Category", fontsize=15)
plt.ylabel("Sales and Profit", fontsize=15)
plt.title("Sales and Profit distribution among Categories",fontsize=18)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.8))
plt.show()

# %% [markdown]
# **Observations**:
#  - Sales of Office Supplies category is high as well as Profit is more.
#  - Sales of Furniture category is high were there is a little Profit.

# %% [markdown]
# ## >> Sub-Category wise Analysis

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='Sub-Category', y='Profit', data=df, palette="CMRmap")
plt.xticks(rotation=70)
plt.title("Barplot of Sub-Category and Profit", fontsize = 18)
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='Sub-Category', y='Sales', data=df, palette="CMRmap")
plt.xticks(rotation=70)
plt.title("Barplot of Sub-Category and Sales", fontsize = 18)
plt.show()

# %%
scsp = df.groupby("Sub-Category")[["Sales","Profit"]].sum().sort_values(by=["Profit"], ascending = False)
scsp.plot(kind="bar", figsize=(12,5), fontsize=13, color = ["orange", "green"])
plt.xticks(rotation=90)
plt.xlabel("Sub-Category", fontsize=15)
plt.ylabel("Sales and Profit", fontsize=15)
plt.title("Sales and Profit distribution among Sub-Categories", fontsize=20)
plt.show()

# %% [markdown]
# - **We can conclude from above plots that :**
#  - Papers shows highest profit with moderate sales and
#  - Tables shows least profit with higher sales.

# %% [markdown]
# ## >> Relation between Sales and Discount

# %%
sns.lineplot(x="Discount",y="Sales", data=df)
plt.show()

# %% [markdown]
# - Sales increase and sometimes decrease with increase in Discount.

# %% [markdown]
# ## >> Relation between Profit and Discount

# %%
df["Discount"].corr(df["Profit"])
# Out:
# -0.4977225124626846

# %%
sns.lineplot(x="Discount",y="Profit", data=df)
plt.show()

# %% [markdown]
# - **Observation**: Profit and Discount have negative correlation, i.e. when one increases, the other decreases or we can say they are inversely proportional.

# %% [markdown]
# ## >> Relationship between Sales, Profit and Discount

# %%
plt.style.use("seaborn")
sns.set(font_scale=1.3)
df.plot(kind="scatter",x="Sales",y="Profit",c="Discount", s = 20, fontsize = 14, cmap="plasma")
plt.title("Dependence among Sales, Profit and Discount",fontsize = 18)
plt.show()

# %% [markdown]
# ### We can observe from plot that:
#  - Discount is inversely proportional to Profit(i.e. higher discount implies low profit amount and even loss(negative profit)).
#  - Discount and Sales have a lesser correlation but as Discount increases, Sales decreases.
#  - When Sales increase, Profit also increases.

# %% [markdown]
# # Conclusion

# %% [markdown]
# - *Focus more on fields where there is loss, less sales, drawbacks of more discount, & least preferred products. Because working on those fields can bring the superstore business to sustained growth.*
# <p>&nbsp;</p>
#
# - *We need to minimize discounts as these are increasing losses(decrease profit) and the sales have also been reduced.*
# <p>&nbsp;</p>
#
# - *Keep more focus over the cities with most buyers and maximum Sales and Profit, i.e. "California" and "New York".*
# <p>&nbsp;</p>
#
# - *Sales in Office Supplies category can be increased or focused more as we can earn more Profit on that.*
# <p>&nbsp;</p>
#
# - *We need to focus on Standard Class more as it brings most profit and sales.*
# <p>&nbsp;</p>
#
# - *Sales in 'Fasteners','labels'and 'Art' category are so less. So, we have to concentrate on these Sub-category businesses more.*
# <p>&nbsp;</p>
#
# - *Sales are mostly done in Western followed by Eastern regions with most profit. So, the sales can be increased in these so as to earn more profit.*
# <p>&nbsp;</p>
#
# - *So as to increase more sales and profit, Consumer segment should be encouraged more than used before.*
